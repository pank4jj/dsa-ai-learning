# %% [markdown]
# ## Strings Demo

# %% [markdown]
# ### 1. Strings in Python

# %% [markdown]
# #### Ways of creating a String

# %%
str1 = 'This is a string in Python'
print(str1)
print(type(str1))
# Out:
# This is a string in Python
# <class 'str'>

# %%
str2 = "This is also a string in Python"
print(str2)
print(type(str2))
# Out:
# This is also a string in Python
# <class 'str'>

# %%
str3 = '''This is a string within triple quotes'''
print(str3)
print(type(str3))
# Out:
# This is a string within triple quotes
# <class 'str'>

# %%
str4 = """This is also a string within triple quotes"""
print(str4)
print(type(str4))
# Out:
# This is also a string within triple quotes
# <class 'str'>

# %%
print('Hi "John"')
# Out:
# Hi "John"

# %%
print('''This is a 
multi-line string that spans
multiple lines''')
# Out:
# This is a
# multi-line string that spans
# multiple lines

# %%
print('This is a \
multi-line string that spans \
multiple lines')
# Out:
# This is a multi-line string that spans multiple lines

# %% [markdown]
# #### Accessing characters of a String

# %%
str1
# Out:
# 'This is a string in Python'

# %%
str1[0]
# Out:
# 'T'

# %%
str1[-1]
# Out:
# 'n'

# %%
str1[4:10]
# Out:
# ' is a '

# %% [markdown]
# ### 2. Properties of Strings

# %% [markdown]
# #### Immutable

# %%
str1 = 'Hello'
print(id(str1))

str1 = str1 + ' World'
print(str1)
print(id(str1))
# Out:
# 1845573784832
# Hello World
# 1845573979824

# %% [markdown]
# #### Iterable

# %%
str1
# Out:
# 'Hello World'

# %%
for ch in str1:
    print(ch, end='')
# Out:
# Hello World

# %% [markdown]
# #### Slicing

# %%
str1
# Out:
# 'Hello World'

# %%
str1[2:5]
# Out:
# 'llo'

# %%
str1[1:9]
# Out:
# 'ello Wor'

# %%
str1[1:9:2]
# Out:
# 'el o'

# %% [markdown]
# #### Unicode

# %%
str1
# Out:
# 'Hello World'

# %%
ord('a'), ord('z')
# Out:
# (97, 122)

# %%
ord('A')
# Out:
# 65

# %%
ord('&')
# Out:
# 38

# %%
for ch in str1:
    print(ch, ord(ch))
# Out:
# H 72
# e 101
# l 108
# l 108
# o 111
#   32
# W 87
# o 111
# r 114
# l 108
# d 100

# %% [markdown]
# #### Concatenation

# %%
s1 = 'Data'
s2 = 'Science'

s1 + ' ' + s2
# Out:
# 'Data Science'

# %% [markdown]
# #### Repetition

# %%
s1
# Out:
# 'Data'

# %%
s1 * 3
# Out:
# 'DataDataData'

# %%
s2 = 'abc123gh'
print(type(s2[4]))
# Out:
# <class 'str'>

# %% [markdown]
# ### 3. Common String Functions

# %%
str1 = 'Data SCIEnce'

print(str1)
print(id(str1))
# Out:
# Data SCIEnce
# 1845574069872

# %% [markdown]
# #### `lower`

# %%
lower_str1 = str1.lower()

print(lower_str1)
print(id(lower_str1))
# Out:
# data science
# 1845574069488

# %%
str1
# Out:
# 'Data SCIEnce'

# %% [markdown]
# #### `upper`

# %%
str1.upper()
# Out:
# 'DATA SCIENCE'

# %%
str2 = 'This is 123 ABC'

print(str2.lower())
print(str2.upper())
# Out:
# this is 123 abc
# THIS IS 123 ABC

# %% [markdown]
# #### `strip`

# %%
str3 = '   data science  '

# %%
str3.strip()
# Out:
# 'data science'

# %%
str4 = '$$$$###data science#############@@@@@'

str4.strip('$').strip('@').strip('#')
# Out:
# 'data science'

# %% [markdown]
# #### `replace`

# %%
str1 = 'Data Science'
str1
# Out:
# 'Data Science'

# %%
str1.replace('Science', 'Analysis')
# Out:
# 'Data Analysis'

# %%
str1.replace('a', 'z')
# Out:
# 'Dztz Science'

# %%
str2 = 'Data Science and Data Engineering'
str2
# Out:
# 'Data Science and Data Engineering'

# %%
str2.replace('Data', 'data', 1)
# Out:
# 'data Science and Data Engineering'

# %% [markdown]
# #### `split`

# %%
str2
# Out:
# 'Data Science and Data Engineering'

# %%
str2.split()
# Out:
# ['Data', 'Science', 'and', 'Data', 'Engineering']

# %%
type(str2), type(str2.split())
# Out:
# (str, list)

# %%
str3 = 'Data-Science-and-Data-Engineering'
str3
# Out:
# 'Data-Science-and-Data-Engineering'

# %%
str3.split('-')
# Out:
# ['Data', 'Science', 'and', 'Data', 'Engineering']

# %%
str3.split('-', 3)
# Out:
# ['Data', 'Science', 'and', 'Data-Engineering']

# %%
str2.split('Data')
# Out:
# ['', ' Science and ', ' Engineering']

# %%
name = 'Mr. James Anderson'

sal, full_name = name.split(maxsplit=1)
print(sal)
print(full_name)
# Out:
# Mr.
# James Anderson

# %% [markdown]
# #### `join`

# %%
list1 = ['My', 'name', 'is', 'Jack']
list1
# Out:
# ['My', 'name', 'is', 'Jack']

# %%
' '.join(list1)
# Out:
# 'My name is Jack'

# %%
'--'.join(list1)
# Out:
# 'My--name--is--Jack'

# %%
'   '.join(list1)
# Out:
# 'My   name   is   Jack'

# %%
' 123 '.join(list1)
# Out:
# 'My 123 name 123 is 123 Jack'
